# %%
import pandas as pd
import numpy as np
import random
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

import openai
import os
import json

from collections import Counter

# %%
from openai import OpenAI 

client = OpenAI(
    # This is the default and can be omitted
    api_key= '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',
)

# %%
data = pd.read_csv('./sample_data_coex_visitors_visits_20171201_20180105.csv', sep=',', skiprows = 3)
data = data[~data['addr'].isnull()]
data = data[data['addr'].str.contains('서울')]
data
# Out:
#        local_datehour     pid   placename                tag  \
# 2       2017-12-09 00   23467          CU              등촌원룸점
# 3       2017-12-09 12   86057   서울9호선 증미역       종합운동장 방면 2-4
# 4       2017-12-09 12   86066  서울9호선 신목동역       종합운동장 방면 2-4
# 5       2017-12-09 13  208705     이맛콩나물국밥              삼성1호점
# 6       2017-12-09 17   84592  서울9호선 봉은사역          개화 방면 2-4
# ...               ...     ...         ...                ...
# 773509  2018-01-02 08  218736  스타필드 코엑스몰점          /코즈니/준오헤어
# 773510  2018-01-02 11  255314    유명국양평해장국                NaN
# 773511  2018-01-03 15  218727  스타필드 코엑스몰점  /케리마켓/ANLE COFFEE
# 773512  2018-01-04 15   88341   서울6호선 합정역          응암순환행 6-4
# 773514  2018-01-04 16    9814     이마트 은평점               /비식품
#
#                               cat                      lat_lng  \
# 2               Convenience Store  37.5565109631,126.860730127
# 3                  Subway Station  37.5580690136,126.860647984
# 4                  Subway Station   37.5441703286,126.88310042
# 5         Korean Food Restaurants  37.5102950657,127.057353344
# 6                  Subway Station   37.5142419355,127.06028413
# ...                           ...                          ...
# 773509      Outlet/ Shopping Mall  37.5093729161,127.059693374
# 773510    Korean Food Restaurants  37.5164864303,127.018625519
# 773511      Outlet/ Shopping Mall    37.509522385,127.05979798
# 773512             Subway Station  37.5489424459,126.913731247
# 773514  Discount Department Store  37.6005156078,126.920202412
#
#                      addr                                      hash_uid
# 2          서울 강서구 등촌동 636  AACepmlRCBduWs47hBiedMwYEXaoAdQfQ+gZuNjcJnE=
# 3       서울 강서구 등촌동 666-40  AACepmlRCBduWs47hBiedMwYEXaoAdQfQ+gZuNjcJnE=
# 4        서울 양천구 목동 138-19  AACepmlRCBduWs47hBiedMwYEXaoAdQfQ+gZuNjcJnE=
# 5       서울 강남구 삼성동 153-57  AACepmlRCBduWs47hBiedMwYEXaoAdQfQ+gZuNjcJnE=
# 6        서울 강남구 삼성동 111-8  AACepmlRCBduWs47hBiedMwYEXaoAdQfQ+gZuNjcJnE=
# ...                   ...                                           ...
# 773509   서울 강남구 삼성동 159-9  //kIAIl1UY8yg6bTw21m0ubi1fOG1jVal7Z8FDQv19o=
# 773510   서울 서초구 잠원동 13-12  //kIAIl1UY8yg6bTw21m0ubi1fOG1jVal7Z8FDQv19o=
# 773511   서울 강남구 삼성동 159-9  //kIAIl1UY8yg6bTw21m0ubi1fOG1jVal7Z8FDQv19o=
# 773512     서울 마포구 합정동 420  //kIAIl1UY8yg6bTw21m0ubi1fOG1jVal7Z8FDQv19o=
# 773514    서울 은평구 응암동 90-1  //kIAIl1UY8yg6bTw21m0ubi1fOG1jVal7Z8FDQv19o=
#
# [614401 rows x 8 columns]

# %%
new_data = pd.DataFrame()
new_data['hash_uid'] = data['hash_uid']
# new_data['date'] = pd.to_datetime(data['local_datehour'], format='%Y-%m-%d %H').dt.date
# new_data['hour'] = pd.to_datetime(data['local_datehour'], format='%Y-%m-%d %H').dt.hour
new_data['date'] = data['local_datehour'].str.split(" ", expand = True)[0]
new_data['hour'] = data['local_datehour'].str.split(" ", expand = True)[1]
new_data['place']= data['placename'] + ' ' + data['tag'].fillna('')
new_data['category'] = data['cat']
new_data['address'] = data['addr']

new_data.reset_index(inplace=True, drop=True)
new_data
# Out:
#                                             hash_uid        date hour  \
# 0       AACepmlRCBduWs47hBiedMwYEXaoAdQfQ+gZuNjcJnE=  2017-12-09   00
# 1       AACepmlRCBduWs47hBiedMwYEXaoAdQfQ+gZuNjcJnE=  2017-12-09   12
# 2       AACepmlRCBduWs47hBiedMwYEXaoAdQfQ+gZuNjcJnE=  2017-12-09   12
# 3       AACepmlRCBduWs47hBiedMwYEXaoAdQfQ+gZuNjcJnE=  2017-12-09   13
# 4       AACepmlRCBduWs47hBiedMwYEXaoAdQfQ+gZuNjcJnE=  2017-12-09   17
# ...                                              ...         ...  ...
# 614396  //kIAIl1UY8yg6bTw21m0ubi1fOG1jVal7Z8FDQv19o=  2018-01-02   08
# 614397  //kIAIl1UY8yg6bTw21m0ubi1fOG1jVal7Z8FDQv19o=  2018-01-02   11
# 614398  //kIAIl1UY8yg6bTw21m0ubi1fOG1jVal7Z8FDQv19o=  2018-01-03   15
# 614399  //kIAIl1UY8yg6bTw21m0ubi1fOG1jVal7Z8FDQv19o=  2018-01-04   15
# 614400  //kIAIl1UY8yg6bTw21m0ubi1fOG1jVal7Z8FDQv19o=  2018-01-04   16
#
#                                place                   category  \
# 0                           CU 등촌원룸점          Convenience Store
# 1             서울9호선 증미역 종합운동장 방면 2-4             Subway Station
# 2            서울9호선 신목동역 종합운동장 방면 2-4             Subway Station
# 3                      이맛콩나물국밥 삼성1호점    Korean Food Restaurants
# 4               서울9호선 봉은사역 개화 방면 2-4             Subway Station
# ...                              ...                        ...
# 614396          스타필드 코엑스몰점 /코즈니/준오헤어      Outlet/ Shopping Mall
# 614397                     유명국양평해장국     Korean Food Restaurants
# 614398  스타필드 코엑스몰점 /케리마켓/ANLE COFFEE      Outlet/ Shopping Mall
# 614399           서울6호선 합정역 응암순환행 6-4             Subway Station
# 614400                  이마트 은평점 /비식품  Discount Department Store
#
#                   address
# 0          서울 강서구 등촌동 636
# 1       서울 강서구 등촌동 666-40
# 2        서울 양천구 목동 138-19
# 3       서울 강남구 삼성동 153-57
# 4        서울 강남구 삼성동 111-8
# ...                   ...
# 614396   서울 강남구 삼성동 159-9
# 614397   서울 서초구 잠원동 13-12
# 614398   서울 강남구 삼성동 159-9
# 614399     서울 마포구 합정동 420
# 614400    서울 은평구 응암동 90-1
#
# [614401 rows x 6 columns]

# %%
form1 = new_data[new_data['hash_uid'] == 'AACepmlRCBduWs47hBiedMwYEXaoAdQfQ+gZuNjcJnE='].drop('hash_uid', axis=1)

# %%
string_test = new_data[new_data['hash_uid'] == 'AACepmlRCBduWs47hBiedMwYEXaoAdQfQ+gZuNjcJnE='].drop('hash_uid', axis=1).to_string()

# %%
import re

test_result = 'index' + re.sub('  +', ',', string_test)
test_result = re.sub('date hour', 'date,hour', test_result)
print(test_result)
# Out:
# index,date,hour,place,category,address
# 0,2017-12-09,00,CU 등촌원룸점,Convenience Store,서울 강서구 등촌동 636
# 1,2017-12-09,12,서울9호선 증미역 종합운동장 방면 2-4,Subway Station,서울 강서구 등촌동 666-40
# 2,2017-12-09,12,서울9호선 신목동역 종합운동장 방면 2-4,Subway Station,서울 양천구 목동 138-19
# 3,2017-12-09,13,이맛콩나물국밥 삼성1호점,Korean Food Restaurants,서울 강남구 삼성동 153-57
# 4,2017-12-09,17,서울9호선 봉은사역 개화 방면 2-4,Subway Station,서울 강남구 삼성동 111-8
# 5,2017-12-09,17,서울2호선 당산역 내선 9-1,Subway Station,서울 영등포구 당산동6가 227-1
# 6,2017-12-09,18,헬로인디북스,Bookstore,서울 마포구 연남동 227-16
# 7,2017-12-09,18,수부니흐,Western Food Restaurants,서울 마포구 연남동 390-42
# 8,2017-12-09,18,교동집,Others(Restaurants),서울 마포구 동교동 153-8
# 9,2017-12-09,21,커피랩,Coffee Shop,서울 마포구 서교동 327-19
# 10,2017-12-10,13,스타필드 코엑스몰점/홍대돈부리 코엑스몰점,Japanese Food Restaurants,서울 강남구 삼성동 159
# 11,2017-12-24,13,서울1호선 용산역 소요산행 9-1,Subway Station,서울 용산구 한강로3가 40-999
# 12,2017-12-24,14,서울3호선 종로3가역 대화행 5-1 / 오금행 6-4,Subway Station,서울 종로구 묘동 20-5
# 13,2017-12-24,22,서울1호선 용산역 소요산행 10-4,Subway Station,서울 용산구 한강로3가 40-999
# 14,2017-12-31,13,아이파크몰/세븐일레븐 용산역점,Convenience Store,서울 용산구 한강로3가 40-999
# 15,2017-12-31,22,경의중앙선 공덕역 지평행 8-4,Subway Station,서울 마포구 도화동 25-13
# 16,2018-01-01,04,서울1호선 용산역 소요산행 7-1,Subway Station,서울 용산구 한강로3가 40-999
# 17,2018-01-01,04,TOUS les JOURS 용산역사점,Bakery,서울 용산구 한강로3가 40-999
# 18,2018-01-01,04,아이파크몰/세븐일레븐 용산역점,Convenience Store,서울 용산구 한강로3가 40-999
# 19,2018-01-01,04,서울1호선 용산역 소요산행 10-4,Subway Station,서울 용산구 한강로3가 40-999

# %%
# format 2
form2 = new_data[new_data['hash_uid'] == 'AACepmlRCBduWs47hBiedMwYEXaoAdQfQ+gZuNjcJnE='].drop('hash_uid', axis=1)
form2 = form2[['place', 'category', 'address', 'date', 'hour']]
form2 = form2.sort_values('place').reset_index(drop=True)

# %%
string_form2 = form2.to_string()
string_form2 = 'index' + re.sub('  +', ',', string_form2)
string_form2 = re.sub('date hour', 'date,hour', string_form2)
print(string_form2)
# Out:
# index,place,category,address,date,hour
# 0,CU 등촌원룸점,Convenience Store,서울 강서구 등촌동 636,2017-12-09,00
# 1,TOUS les JOURS 용산역사점,Bakery,서울 용산구 한강로3가 40-999,2018-01-01,04
# 2,경의중앙선 공덕역 지평행 8-4,Subway Station,서울 마포구 도화동 25-13,2017-12-31,22
# 3,교동집,Others(Restaurants),서울 마포구 동교동 153-8,2017-12-09,18
# 4,서울1호선 용산역 소요산행 10-4,Subway Station,서울 용산구 한강로3가 40-999,2017-12-24,22
# 5,서울1호선 용산역 소요산행 10-4,Subway Station,서울 용산구 한강로3가 40-999,2018-01-01,04
# 6,서울1호선 용산역 소요산행 7-1,Subway Station,서울 용산구 한강로3가 40-999,2018-01-01,04
# 7,서울1호선 용산역 소요산행 9-1,Subway Station,서울 용산구 한강로3가 40-999,2017-12-24,13
# 8,서울2호선 당산역 내선 9-1,Subway Station,서울 영등포구 당산동6가 227-1,2017-12-09,17
# 9,서울3호선 종로3가역 대화행 5-1 / 오금행 6-4,Subway Station,서울 종로구 묘동 20-5,2017-12-24,14
# 10,서울9호선 봉은사역 개화 방면 2-4,Subway Station,서울 강남구 삼성동 111-8,2017-12-09,17
# 11,서울9호선 신목동역 종합운동장 방면 2-4,Subway Station,서울 양천구 목동 138-19,2017-12-09,12
# 12,서울9호선 증미역 종합운동장 방면 2-4,Subway Station,서울 강서구 등촌동 666-40,2017-12-09,12
# 13,수부니흐,Western Food Restaurants,서울 마포구 연남동 390-42,2017-12-09,18
# 14,스타필드 코엑스몰점/홍대돈부리 코엑스몰점,Japanese Food Restaurants,서울 강남구 삼성동 159,2017-12-10,13
# 15,아이파크몰/세븐일레븐 용산역점,Convenience Store,서울 용산구 한강로3가 40-999,2018-01-01,04
# 16,아이파크몰/세븐일레븐 용산역점,Convenience Store,서울 용산구 한강로3가 40-999,2017-12-31,13
# 17,이맛콩나물국밥 삼성1호점,Korean Food Restaurants,서울 강남구 삼성동 153-57,2017-12-09,13
# 18,커피랩,Coffee Shop,서울 마포구 서교동 327-19,2017-12-09,21
# 19,헬로인디북스,Bookstore,서울 마포구 연남동 227-16,2017-12-09,18

# %%
import json
# format 3

form1.to_json('form3.json', orient = 'index')
with open('./form3.json') as f:
    form3 = json.load(f)
form3
# Out:
# {'0': {'date': '2017-12-09',
#   'hour': '00',
#   'place': 'CU 등촌원룸점',
#   'category': 'Convenience Store',
#   'address': '서울 강서구 등촌동 636'},
#  '1': {'date': '2017-12-09',
#   'hour': '12',
#   'place': '서울9호선 증미역 종합운동장 방면 2-4',
#   'category': 'Subway Station',
#   'address': '서울 강서구 등촌동 666-40'},
#  '2': {'date': '2017-12-09',
#   'hour': '12',
#   'place': '서울9호선 신목동역 종합운동장 방면 2-4',
#   'category': 'Subway Station',
#   'address': '서울 양천구 목동 138-19'},
#  '3': {'date': '2017-12-09',
#   'hour': '13',
#   'place': '이맛콩나물국밥 삼성1호점',
#   'category': 'Korean Food Restaurants',
#   'address': '서울 강남구 삼성동 153-57'},
#  '4': {'date': '2017-12-09',
#   'hour': '17',
#   'place': '서울9호선 봉은사역 개화 방면 2-4',
#   'category': 'Subway Station',
#   'address': '서울 강남구 삼성동 111-8'},
#  '5': {'date': '2017-12-09',
#   'hour': '17',
#   'place': '서울2호선 당산역 내선 9-1',
#   'category': 'Subway Station',
#   'address': '서울 영등포구 당산동6가 227-1'},
#  '6': {'date': '2017-12-09',
#   'hour': '18',
#   'place': '헬로인디북스 ',
#   'category': 'Bookstore',
#   'address': '서울 마포구 연남동 227-16'},
#  '7': {'date': '2017-12-09',
#   'hour': '18',
#   'place': '수부니흐 ',
#   'category': 'Western Food Restaurants',
#   'address': '서울 마포구 연남동 390-42'},
#  '8': {'date': '2017-12-09',
#   'hour': '18',
#   'place': '교동집 ',
#   'category': 'Others(Restaurants)',
#   'address': '서울 마포구 동교동 153-8'},
#  '9': {'date': '2017-12-09',
#   'hour': '21',
#   'place': '커피랩 ',
#   'category': 'Coffee Shop',
#   'address': '서울 마포구 서교동 327-19'},
#  '10': {'date': '2017-12-10',
#   'hour': '13',
#   'place': '스타필드 코엑스몰점/홍대돈부리 코엑스몰점',
#   'category': 'Japanese Food Restaurants',
#   'address': '서울 강남구 삼성동 159'},
#  '11': {'date': '2017-12-24',
#   'hour': '13',
#   'place': '서울1호선 용산역 소요산행 9-1',
#   'category': 'Subway Station',
#   'address': '서울 용산구 한강로3가 40-999'},
#  '12': {'date': '2017-12-24',
#   'hour': '14',
#   'place': '서울3호선 종로3가역 대화행 5-1 / 오금행 6-4',
#   'category': 'Subway Station',
#   'address': '서울 종로구 묘동 20-5'},
#  '13': {'date': '2017-12-24',
#   'hour': '22',
#   'place': '서울1호선 용산역 소요산행 10-4',
#   'category': 'Subway Station',
#   'address': '서울 용산구 한강로3가 40-999'},
#  '14': {'date': '2017-12-31',
#   'hour': '13',
#   'place': '아이파크몰/세븐일레븐 용산역점',
#   'category': 'Convenience Store',
#   'address': '서울 용산구 한강로3가 40-999'},
#  '15': {'date': '2017-12-31',
#   'hour': '22',
#   'place': '경의중앙선 공덕역 지평행 8-4',
#   'category': 'Subway Station',
#   'address': '서울 마포구 도화동 25-13'},
#  '16': {'date': '2018-01-01',
#   'hour': '04',
#   'place': '서울1호선 용산역 소요산행 7-1',
#   'category': 'Subway Station',
#   'address': '서울 용산구 한강로3가 40-999'},
#  '17': {'date': '2018-01-01',
#   'hour': '04',
#   'place': 'TOUS les JOURS 용산역사점',
#   'category': 'Bakery',
#   'address': '서울 용산구 한강로3가 40-999'},
#  '18': {'date': '2018-01-01',
#   'hour': '04',
#   'place': '아이파크몰/세븐일레븐 용산역점',
#   'category': 'Convenience Store',
#   'address': '서울 용산구 한강로3가 40-999'},
#  '19': {'date': '2018-01-01',
#   'hour': '04',
#   'place': '서울1호선 용산역 소요산행 10-4',
#   'category': 'Subway Station',
#   'address': '서울 용산구 한강로3가 40-999'}}

# %%
# format 4
form2.to_json('form4.json', orient = 'index')
with open('./form4.json') as f:
    form4 = json.load(f)
form4
# Out:
# {'0': {'place': 'CU 등촌원룸점',
#   'category': 'Convenience Store',
#   'address': '서울 강서구 등촌동 636',
#   'date': '2017-12-09',
#   'hour': '00'},
#  '1': {'place': 'TOUS les JOURS 용산역사점',
#   'category': 'Bakery',
#   'address': '서울 용산구 한강로3가 40-999',
#   'date': '2018-01-01',
#   'hour': '04'},
#  '2': {'place': '경의중앙선 공덕역 지평행 8-4',
#   'category': 'Subway Station',
#   'address': '서울 마포구 도화동 25-13',
#   'date': '2017-12-31',
#   'hour': '22'},
#  '3': {'place': '교동집 ',
#   'category': 'Others(Restaurants)',
#   'address': '서울 마포구 동교동 153-8',
#   'date': '2017-12-09',
#   'hour': '18'},
#  '4': {'place': '서울1호선 용산역 소요산행 10-4',
#   'category': 'Subway Station',
#   'address': '서울 용산구 한강로3가 40-999',
#   'date': '2017-12-24',
#   'hour': '22'},
#  '5': {'place': '서울1호선 용산역 소요산행 10-4',
#   'category': 'Subway Station',
#   'address': '서울 용산구 한강로3가 40-999',
#   'date': '2018-01-01',
#   'hour': '04'},
#  '6': {'place': '서울1호선 용산역 소요산행 7-1',
#   'category': 'Subway Station',
#   'address': '서울 용산구 한강로3가 40-999',
#   'date': '2018-01-01',
#   'hour': '04'},
#  '7': {'place': '서울1호선 용산역 소요산행 9-1',
#   'category': 'Subway Station',
#   'address': '서울 용산구 한강로3가 40-999',
#   'date': '2017-12-24',
#   'hour': '13'},
#  '8': {'place': '서울2호선 당산역 내선 9-1',
#   'category': 'Subway Station',
#   'address': '서울 영등포구 당산동6가 227-1',
#   'date': '2017-12-09',
#   'hour': '17'},
#  '9': {'place': '서울3호선 종로3가역 대화행 5-1 / 오금행 6-4',
#   'category': 'Subway Station',
#   'address': '서울 종로구 묘동 20-5',
#   'date': '2017-12-24',
#   'hour': '14'},
#  '10': {'place': '서울9호선 봉은사역 개화 방면 2-4',
#   'category': 'Subway Station',
#   'address': '서울 강남구 삼성동 111-8',
#   'date': '2017-12-09',
#   'hour': '17'},
#  '11': {'place': '서울9호선 신목동역 종합운동장 방면 2-4',
#   'category': 'Subway Station',
#   'address': '서울 양천구 목동 138-19',
#   'date': '2017-12-09',
#   'hour': '12'},
#  '12': {'place': '서울9호선 증미역 종합운동장 방면 2-4',
#   'category': 'Subway Station',
#   'address': '서울 강서구 등촌동 666-40',
#   'date': '2017-12-09',
#   'hour': '12'},
#  '13': {'place': '수부니흐 ',
#   'category': 'Western Food Restaurants',
#   'address': '서울 마포구 연남동 390-42',
#   'date': '2017-12-09',
#   'hour': '18'},
#  '14': {'place': '스타필드 코엑스몰점/홍대돈부리 코엑스몰점',
#   'category': 'Japanese Food Restaurants',
#   'address': '서울 강남구 삼성동 159',
#   'date': '2017-12-10',
#   'hour': '13'},
#  '15': {'place': '아이파크몰/세븐일레븐 용산역점',
#   'category': 'Convenience Store',
#   'address': '서울 용산구 한강로3가 40-999',
#   'date': '2018-01-01',
#   'hour': '04'},
#  '16': {'place': '아이파크몰/세븐일레븐 용산역점',
#   'category': 'Convenience Store',
#   'address': '서울 용산구 한강로3가 40-999',
#   'date': '2017-12-31',
#   'hour': '13'},
#  '17': {'place': '이맛콩나물국밥 삼성1호점',
#   'category': 'Korean Food Restaurants',
#   'address': '서울 강남구 삼성동 153-57',
#   'date': '2017-12-09',
#   'hour': '13'},
#  '18': {'place': '커피랩 ',
#   'category': 'Coffee Shop',
#   'address': '서울 마포구 서교동 327-19',
#   'date': '2017-12-09',
#   'hour': '21'},
#  '19': {'place': '헬로인디북스 ',
#   'category': 'Bookstore',
#   'address': '서울 마포구 연남동 227-16',
#   'date': '2017-12-09',
#   'hour': '18'}}

# %%
def totext(dataframe):
    
    df = dataframe.copy()
    df = df.sort_values(by=['date', 'hour'])

    result = "A person's visit history from " + df.loc[0, 'date'][5:10] + df.loc[0, 'date'][4] + df.loc[0, 'date'][0:4] \
       + " to " + df.loc[len(df) - 1, 'date'][5:10] + df.loc[len(df) - 1, 'date'][4] + df.loc[len(df) - 1, 'date'][0:4] + " is as follows:"
    
    # result = "A person's visit history from " + str(df.loc[0, 'date'].month) + "-" + str(df.loc[0, 'date'].day) + "-" + str(df.loc[0, 'date'].year) \
    #    + " to " + str(df.loc[len(df) - 1, 'date'].month) + "-" + str(df.loc[len(df) - 1, 'date'].day) + "-" + str(df.loc[len(df) - 1, 'date'].year) + " is as follows:\n"
    
    for i in range(len(df)):
        irow = df.iloc[i, :]

        if irow['place'][-1] == " ":
            pn = str(irow['place'][:-1])
        else:
            pn = str(irow['place'])

        if i == 0:
            result += "The person visited a " + irow['category'].lower() + " named " + pn + " located at " + irow[
                'address'] + " at " + str(irow['hour']) + " on " + irow['date'][5:10] + irow['date'][4] + irow['date'][0:4]
        elif i == len(df) - 1:
            result += ", and a " + irow['category'].lower() + " named " + pn + " located at " + irow['address'] + " at " + \
                      str(irow['hour']) + " on " + irow['date'][5:10] + irow['date'][4] + irow['date'][0:4] + "."
        else:
            result += ", a " + irow['category'].lower() + " named " + pn + " located at " + irow['address'] + " at " + \
                      str(irow['hour']) + " on " + irow['date'][5:10] + irow['date'][4] + irow['date'][0:4]

    return result

# %%
def totextvisited(dataframe):
    
    df = dataframe.copy()
    df = df.sort_values(by = ['date', 'hour'])

    result = "A person's visit history from " + df.loc[0, 'date'][5:10] + df.loc[0, 'date'][4] + df.loc[0, 'date'][0:4] \
          + " to " + df.loc[len(df) - 1, 'date'][5:10] + df.loc[len(df) - 1, 'date'][4] + df.loc[len(df) - 1, 'date'][0:4] + " is as follows: "

    
    visited = {}
    visitedcataddr = {}
    
    for i in range(len(df)):
        irow = df.iloc[i, :]
        
        
        if irow['place'][-1] == " ":
        
            pn = str(irow['place'][:-1])

        else:
            pn = str(irow['place'])


        
        if pn in visited.keys():      
            visited[pn] += ", at " + str(irow['hour']) + " on " + irow['date'][5:10] + irow['date'][4] + irow['date'][0:4]
            
        elif pn not in visited.keys():
            visited.update({pn : " at " + str(irow['hour']) + " on " + irow['date'][5:10] + irow['date'][4] + irow['date'][0:4]})
            visitedcataddr.update({pn : [irow['category'].lower(), irow['address']]})
            

    result += "The person visited"
    for key, value in visited.items():
        if key == list(visited.keys())[-1]:
            result += " a " + visitedcataddr[key][0] + " named " + key \
                    + " located at " + visitedcataddr[key][1] + value + "."
        else:
            result += " a " + visitedcataddr[key][0] + " named " + key \
                    + " located at " + visitedcataddr[key][1] + value + ","
                
    return result

# %%
# format 5
totext(form1)
# Out:
on 12-09-2017, a coffee shop named 커피랩 located at 서울 마포구 서교동 327-19 at 21 on 12-09-2017, a japanese food restaurants named 스타필드 코엑스몰점/홍대돈부리 코엑스몰점 located at 서울 강남구 삼성동 159 at 13 on 12-10-2017, a subway station named 서울1호선 용산역 소요산행 9-1 located at 서울 용산구 한강로3가 40-999 at 13 on 12-24-2017, a subway station named 서울3호선 종로3가역 대화행 5-1 / 오금행 6-4 located at 서울 종로구 묘동 20-5 at 14 on 12-24-2017, a subway station named 서울1호선 용산역 소요산행 10-4 located at 서울 용산구 한강로3가 40-999 at 22 on 12-24-2017, at 04 on 01-01-2018, a convenience store named 아이파크몰/세븐일레븐 용산역점 located at 서울 용산구 한강로3가 40-999 at 13 on 12-31-2017, at 04 on 01-01-2018, a subway station named 경의중앙선 공덕역 지평행 8-4 located at 서울 마포구 도화동 25-13 at 22 on 12-31-2017, a subway station named 서울1호선 용산역 소요산행 7-1 located at 서울 용산구 한강로3가 40-999 at 04 on 01-01-2018, a bakery named TOUS les JOURS 용산역사점 located at 서울 용산구 한강로3가 40-999 at 04 on 01-01-2018."

# %%
def gpt_api(system_prompt, user_prompt, user_log, model="gpt-3.5-turbo", verbose=False):

    user_prompt += '\n' + user_log
    
    if verbose:
      print(user_prompt)

    messages = [
                {"role": "system", "content": system_prompt}, 
                {"role": "user", "content": user_prompt}
                ]
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0,
    )

    output = response.choices[0].message.content
    token = response.usage.total_tokens
    
    # print('answer : ', output)
    # print('token : ', token)

    return output, token

# %%
user_50plus = new_data['hash_uid'].value_counts()[new_data['hash_uid'].value_counts().values>=50].index
select_user_50plus = [user_50plus[i] for i in random.sample(range(0, len(user_50plus)), 500)]

# %%
cnt = 0
duration_ans = [] 
most_visited_date_ans = []
most_visited_hour_ans = []
most_visited_timestamp_ans = []
longest_time_diff_ans = []


dates_and_places_to_ask = {}
the_dates = []
possible_dates_ans = []
the_places= []
possible_places_ans = []

for i in select_user_50plus:
    # print('----- ',cnt,' -----')
    
    user_log = new_data[new_data['hash_uid'] == i]
    user_log = user_log.drop('hash_uid', axis=1)
    user_log = user_log[-40:]
    # user_log.reset_index(inplace=True, drop=True)
    
    # user_log_shuffle = user_log.sample(frac=1).reset_index(drop=True)
    # user_log_shuffle = user_log.sample(frac = 1)
    
    # 이후 api call에서 저장된 dataframe을 통해 로그를 보낼 예정이라면 따로 저장 필요.
    user_log.to_csv(f'./data/subtasks_lookup/user_log/user_log_{cnt}.csv', index=False)
    # user_log_shuffle.to_csv(f'./data/subtasks_temporal/user_log_shuffle/user_log_shuffle_{cnt}.csv', index=False)

    
    
    for j in random.sample(range(0, len(user_log)), 1):
        the_log = user_log.iloc[j, :]
        the_date = the_log['date']
        the_place = the_log['place']
        dates_and_places_to_ask.update({i : [the_date, the_place]})
        the_dates.append(the_date)
        the_places.append(the_place)
        
    possible_dates_df = user_log[user_log['place'] == the_place]
    possible_dates_ans.append(possible_dates_df['date'].tolist())

    possible_places_df = user_log[user_log['date'] == the_date]
    possible_places_ans.append(possible_places_df['place'].tolist())
    
    
    cnt += 1

# %%
np.save('./data/subtasks_lookup/the_dates', the_dates)
np.save('./data/subtasks_lookup/the_places', the_places)

# %%
the_places = np.load('./data/subtasks_lookup/the_places.npy')
the_dates = np.load('./data/subtasks_lookup/the_dates.npy')
the_places = the_places[:100]
the_dates = the_dates[:100]

# %%
ask_date_form1 = []
ask_date_form2 = []
ask_date_form3 = []
ask_date_form4 = []
ask_date_form5 = []
ask_date_form6 = []

system_prompt = 'You only answer in the following format: year-month-day, Don\'t answer in a sentence.'


for i in range(100):
    # print('------', i, '-------')
    
    user_log = pd.read_csv(f'./data/subtasks_lookup/user_log/user_log_{i}.csv')
    user_log = user_log[-40:]
    user_log.reset_index(inplace=True, drop=True)

    # dates_to_reply = str(dates_ans[i])

    user_prompt = 'Q. When is the date when the person visited ' + str(the_places[i]) + '? If you have several days with the most visits, answer only one date.'
    
    # print('format 1')
    user_log_str = user_log.to_string()
    user_log_form1 = 'index' + re.sub('  +', ',', user_log_str)
    user_log_form1 = re.sub('date hour', 'date,hour', user_log_form1)
    output, tok = gpt_api(system_prompt, user_prompt, user_log_form1)
    ask_date_form1.append(output)
    
    # print('format 2')
    form2_df = user_log[['place', 'category', 'address', 'date', 'hour']]
    form2_df = form2_df.sort_values('place').reset_index(drop=True)
    user_log_form2_str = form2_df.to_string()
    user_log_form2 = 'index' + re.sub('  +', ',', user_log_form2_str)
    user_log_form2 = re.sub('date hour', 'date,hour', user_log_form2)
    output, tok = gpt_api(system_prompt, user_prompt, user_log_form2)
    ask_date_form2.append(output)
    
    # print('format 3')
    user_log.to_json(f'./data/subtasks_lookup/user_log/user_log_{i}_json_temp.json', orient = 'index')
    with open(f'./data/subtasks_lookup/user_log/user_log_{i}_json_temp.json') as f:
        user_log_form3 = json.load(f)
    output, tok = gpt_api(system_prompt, user_prompt, str(user_log_form3))
    ask_date_form3.append(output)
    
    # print('format 4')
    form2_df.to_json(f'./data/subtasks_lookup/user_log/user_log_{i}_json_space.json', orient = 'index')
    with open(f'./data/subtasks_lookup/user_log/user_log_{i}_json_space.json') as f:
        user_log_form4 = json.load(f)
    output, tok = gpt_api(system_prompt, user_prompt, str(user_log_form4))
    ask_date_form4.append(output)
    
    # print('format 5')
    output, tok = gpt_api(system_prompt, user_prompt, totext(user_log))
    ask_date_form5.append(output)
    
    # print('format 6')
    output, tok = gpt_api(system_prompt, user_prompt, totextvisited(user_log))
    ask_date_form6.append(output)

# %%
ask_date_form1_score = []

print('form1')
for ai, bi in zip(possible_dates_ans, ask_date_form1):
    ask_date_form1_score.append(bi in ai)
    if (bi in ai) == False : print(ai, bi)

ask_date_form2_score = []

print('form2')
for ai, bi in zip(possible_dates_ans, ask_date_form2):
    ask_date_form2_score.append(bi in ai)
    if (bi in ai) == False : print(ai, bi)
    
ask_date_form3_score = []

print('form3')
for ai, bi in zip(possible_dates_ans, ask_date_form3):
    ask_date_form3_score.append(bi in ai)
    if (bi in ai) == False : print(ai, bi)
    
ask_date_form4_score = []

print('form4')
for ai, bi in zip(possible_dates_ans, ask_date_form4):
    ask_date_form4_score.append(bi in ai)
    if (bi in ai) == False : print(ai, bi)
# ['2017-12-23', '2017-12-23', '2017-12-23', '2017-12-23', '2017-12-23', '2017-12-23', '2017-12-23', '2017-12-23', '2017-12-23'] 12-23-2017
# ['2017-12-29', '2018-01-04'] 2017-12-27
# ['2017-12-28', '2017-12-29', '2017-12-29', '2017-12-30', '2017-12-31', '2018-01-04', '2018-01-05'] 12-28-2017
# ['2017-12-25', '2017-12-25', '2017-12-26', '2017-12-27', '2017-12-29', '2017-12-29', '2017-12-30', '2017-12-30', '2017-12-31', '2018-01-01', '2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04', '2018-01-05', '2018-01-05'] 12-25-2017
# ['2017-12-13', '2017-12-16', '2017-12-16', '2017-12-24'] 12-13-2017
# ['2017-12-29'] 2018-01-05
# ['2017-12-15'] 2018-01-04

# %%
print(sum(ask_date_form1_score)/100)
print(sum(ask_date_form2_score)/100)
print(sum(ask_date_form3_score)/100)
print(sum(ask_date_form4_score)/100)
print(sum(ask_date_form5_score)/100)
print(sum(ask_date_form6_score)/100)
# Out:
# 0.96
# 0.96
# 0.97
# 0.98
# 0.86
# 0.83

# %% [markdown]
# Ask Place -- given the date, provide the place name

# %%
ask_place_form1 = []
ask_place_form2 = []
ask_place_form3 = []
ask_place_form4 = []
ask_place_form5 = []
ask_place_form6 = []

system_prompt = 'You only answer in the following format: place, Don\'t answer in a sentence.'


for i in range(100):
    # print('------', i, '-------')
    
    user_log = pd.read_csv(f'./data/subtasks_lookup/user_log/user_log_{i}.csv')
    user_log = user_log[-40:]
    user_log.reset_index(inplace=True, drop=True)

    # dates_to_reply = str(dates_ans[i])

    user_prompt = 'Q. Where did the person visited on ' + str(the_dates[i]) + '? If you have several places on that day, answer only one place.'
    
    # print('format 1')
    user_log_str = user_log.to_string()
    user_log_form1 = 'index' + re.sub('  +', ',', user_log_str)
    user_log_form1 = re.sub('date hour', 'date,hour', user_log_form1)
    output, tok = gpt_api(system_prompt, user_prompt, user_log_form1)
    ask_place_form1.append(output)
    
    # print('format 2')
    form2_df = user_log[['place', 'category', 'address', 'date', 'hour']]
    form2_df = form2_df.sort_values('place').reset_index(drop=True)
    user_log_form2_str = form2_df.to_string()
    user_log_form2 = 'index' + re.sub('  +', ',', user_log_form2_str)
    user_log_form2 = re.sub('date hour', 'date,hour', user_log_form2)
    output, tok = gpt_api(system_prompt, user_prompt, user_log_form2)
    ask_place_form2.append(output)
    
    # print('format 3')
    user_log.to_json(f'./data/subtasks_lookup/user_log/user_log_{i}_json_temp.json', orient = 'index')
    with open(f'./data/subtasks_lookup/user_log/user_log_{i}_json_temp.json') as f:
        user_log_form3 = json.load(f)
    output, tok = gpt_api(system_prompt, user_prompt, str(user_log_form3))
    ask_place_form3.append(output)
    
    # print('format 4')
    form2_df.to_json(f'./data/subtasks_lookup/user_log/user_log_{i}_json_space.json', orient = 'index')
    with open(f'./data/subtasks_lookup/user_log/user_log_{i}_json_space.json') as f:
        user_log_form4 = json.load(f)
    output, tok = gpt_api(system_prompt, user_prompt, str(user_log_form4))
    ask_place_form4.append(output)
    
    # print('format 5')
    output, tok = gpt_api(system_prompt, user_prompt, totext(user_log))
    ask_place_form5.append(output)
    
    # print('format 6')
    output, tok = gpt_api(system_prompt, user_prompt, totextvisited(user_log))
    ask_place_form6.append(output)

# %%
ask_place_form1_score = []

print('form1')
for ai, bi in zip(possible_places_ans, ask_place_form1):
    ask_place_form1_score.append(bi in ai)
    if (bi in ai) == False : print(ai, bi)

ask_place_form2_score = []

print('form2')
for ai, bi in zip(possible_places_ans, ask_place_form2):
    ask_place_form2_score.append(bi in ai)
    if (bi in ai) == False : print(ai, bi)
    
ask_place_form3_score = []

print('form3')
for ai, bi in zip(possible_places_ans, ask_place_form3):
    ask_place_form3_score.append(bi in ai)
    if (bi in ai) == False : print(ai, bi)
    
ask_place_form4_score = []

print('form4')
for ai, bi in zip(possible_places_ans, ask_place_form4):
    ask_place_form4_score.append(bi in ai)
    if (bi in ai) == False : print(ai, bi)
    
ask_place_form5_score = []

print('form5')
for ai, bi in zip(possible_places_ans, ask_place_form5):
    ask_place_form5_score.append(bi in ai)
    if (bi in ai) == False : print(ai, bi)
    
ask_place_form6_score = []

print('form6')
for ai, bi in zip(possible_places_ans, ask_place_form6):
    ask_place_form6_score.append(bi in ai)
    if (bi in ai) == False : print(ai, bi)
# Out:
# form1
# ['잇텐고10.5 ', '서울2호선 홍대입구역 내선 3-1 / 외선 8-3', '서울5호선 을지로4가역 방화행 7-4 / 상일동 마천행 2-1', '망원동티라미수 ', '잇텐고10.5 ', 'ETUDE Lounge ', 'CAFE CMENT ', '아름다운 시선 ', '미자카야 ', '서울5호선 왕십리역 상일동 마천행 2-2', '서울5호선 마장역 상일동 마천행 2-2', '서울5호선 청구역 방화행 5-1 / 상일동 마천행 4-3', '서울5호선 5360', '서울5호선 신금호역 상일동 마천행 4-4', '이마트 에브리데이 답십리점'] 잇텐고10.5
# ['서울7호선 상봉역 부평구청 방면 5-1', '브라더후드키친 ', '알베르 '] 브라더후드키친
# ['ARITAUM 잠실지하점', 'CU 서울매트로잠실역점', '다이소 잠실점'] 서울2호선 잠실새내역 외선 3-1
# ['스타벅스 압구정점', 'CGV 압구정점/안성기상영관앞', '스타벅스 압구정점', '스타필드 코엑스몰점 /가가홈&차일드/안동찜닭&해물떡집/반하는보쌈'] 서울 강남구 신사동 609
# ['서울9호선 선정릉역 개화 방면 2-4', 'Innisfree 여의도역점'] 스타필드 코엑스몰점
# ['파르나스몰/KOSNEY 코엑스파르나스점', '파르나스몰/GS25 파르나스타워점', '파르나스몰/수불 삼성파르나스점', '파르나스몰/Saint AUGUSTIN 파르나스몰점', '파르나스몰/수불 삼성파르나스점', '파르나스몰/환공어묵베이커리 ', '파르나스몰/Saint AUGUSTIN 파르나스몰점', '파르나스몰 /무인양품/GS25', '파르나스몰 /커피빈(CBTL)/센트럴라운지', '파르나스몰 /곤트란쉐리에/지올리띠/파이공장', '스타필드 코엑스몰점/스타벅스 코엑스몰점', '스타벅스 스타필드코엑스몰점', '파르나스몰 /에런스로렌콤헤어살롱/에스컬레이터라운지', '파르나스몰/GS25 파르나스타워점'] 스타필드 코엑스몰점
# ['쟝블랑제리 ', '효 스터디룸카페 ', '홈플러스 영등포점 /비식품'] 스타필드 코엑스몰점/버거킹 메가박스점
# ['스타필드 코엑스몰점/STUDIO TOMBOY ', '스타필드 코엑스몰점 /스위트스페이스/양키갠들', '스타필드 코엑스몰점/스위트스페이스 코엑스몰점', '스타필드 코엑스몰점 /할리스커피/다이소', '스타필드 코엑스몰점 /에잇세컨즈/스튜디오톰보이', '스타필드 코엑스몰점 /할리스커피/다이소', '스타필드 코엑스몰점
�/세컨스킨/CC콜렉트/VOV/티렌/더아이잗/더틸버리/베네통/커밍스텝', '현대시티아울렛 가산점 /영캐주얼. 구두. 핸드백액세서리/고체/소다', '현대시티아울렛 가산점/HAZZYS 현대아울렛가산점', '현대시티아울렛 가산점 /여성패션. 골프. 아동/ 앤클라인/아이잗바바/쁘렝땅/요하넥스/캐리스노트/발렌시아'] CU 관악리베로점
# ['현대백화점 압구정본점 /수입부티크 외', '현대백화점 압구정본점 /남성패션/타이/셔츠/골프/아웃도어', '현대백화점 압구정본점 /남성패션 외'] GS25 세곡1단지점
# ['서울5호선 오목교역 상일동 마천행 4-4', '서울5호선 5569', '서울5호선 을지로4가역 방화행 4-3 / 상일동 마천행 5-2', '서울5호선 종로3가역 방화행 4-3 / 상일동 마천행 5-1', '서울2호선 을지로4가역 내선 7-1'] Innisfree 오목교역점
# ['하이마트 양재점', '서울3호선 양재역 대화방면 5-1', '신분당선 청계산입구역 강남방면 2-2', '신세계백화점 강남점 /신세계 푸드마켓/푸드홀', '신세계백화점 강남점 /화장품/잡화/해외유명브랜드', '서울3호선 남부터미널역 오금방면 7-1', '서울3호선 고속터미널역 오금방면 9-1'] IFC몰/ZARA IFC몰점
# ['서울2호선 잠실역 외선 3-1', '서울7호선 고속터미널역 장암 방면 6-4', '서울7호선 가산디지털단지역 장암 방면 6-4', '서울7호선 대림역 장암 방면 6-4', '서울8호선 가락시장역 모란방면 2-2', '서울3호선 고속터미널역 오금방면 3-1'] 분당선 351115
# ['서울9호선 봉은사역 개화 방면 2-4', '스타벅스 양평동점', '서울9호선 당산역 개화방면 4-4/종합운동장방면 1-1'] Cafe 281
# ['본죽 신천점', '맥도날드 잠실신천점'] NC백화점 송파점/자연별곡 가든파이브점
# ['현대백화점 무역센터점 /남성패션'] CGV 송파점
# ['스타필드 코엑스몰점/CJ푸드월드 코엑스몰점/방콕9/비비고/차이나팩토리/제일제면소/투썸플레이스', '우체국 서울무역센타우체국', '스타필드 코엑스몰점/CJ푸드월드 코엑스몰점'] 서울 강남구 삼성동 159
# ['분당선 수서역 수원방면 5-3', '분당선 강남구청역 수원방면 5-3', '분당선 351432', '분당선 351404'] GS25 화양타운점
# ['서울1호선 311574', '서울1호선 311574', '서울1호선 가산디지털단지역 신창방면 7-1', '서울1호선 1808'] 마리오아울렛 1관/공차 마리오아울렛점
# ['서울5호선 천호역 방화행 2-2', '뽀빠이 정형외과 /정형외과', '서울5호선 천호역 방화행 6-4', '서울5호선 5347', '서울5호선 아차산역 상일동 마천행 6-4'] GS25 S군자역점
# ['서울3호선 대치역 대화방면 3-1/오금방면 8-4', '서울3호선 3937', '서울2호선 2070', '채선당 신촌점', '서울2호선 2791'] 2x휘트니스 대치점
# ['청맥호프 방배본점', '풍미보쌈족발 ', '밀레니엄노래방 ', '서울2호선 사당역 외선 3-1', '서울2호선 사당역 외선 9-1'] 밀레니엄노래방
# ['분당선 구룡역 수원방면 5-3', '분당선 한티역 수원방면 5-3'] 대복한우
# ['서울4호선 동대문역사문화공원역 당고개방면 3-1/오이도방면 8-4', '서울4호선 동대문역 당고개방면 2-3'] 서울 종로구 종로6가 70-2
# ['서울5호선 목동역 방화행 2-2', '직화백반 ', '카페리오비 ', '서울1호선 금천구청역 소요산방면 7-1'] GS25 마곡루체점
# ['서울3호선 양재역 오금방면 5-1', '서울3호선 수서역 오금방면 3-1', '서울5호선 5042', '서울5호선 오금역 방화행 6-4', '투썸플레이스 잠실역점', '투썸플레이스 잠실역점', '투썸플레이스 잠실역점', '서울6호선 신당역 봉화산행 8-4 / 응암순환행 1-1'] 서울 강남구 수서동 719
# ['서울2호선 역삼역 외선 9-1', '서울2호선 강남역 외선 5-1', '얌샘김밥 삼성점'] 더차이홍 삼성점
# ['서울5호선 신길역 상일동 마천행 4-4', '서울5호선 영등포구청역 상일동 마천행 4-4', '서울5호선 5538', '서울5호선 여의나루역 방화방면 8-4', '서울5호선 여의도역 상일동 마천행 / 4-4', '서울2호선 문래역 내선 7-1', 'CHADOL HOUSE '] CHADOL HOUSE
# ['서울9호선 종합운동장역 개화방면 2-2', '서울9호선 종합운동장역 (완행)종합운동장 방면 1-1 / 개화 방면 1-1'] 롯데마이슈퍼 코엑스점
# ['서울5호선 애오개역 상일동 마천행 4-4', '제일제면소 쌍림점', 'Wine&Cheese Street '] Wine&Cheese Street
# ['몬비엣 ', '미스터힐링 홍대본점', '오설록 홍대점', '오빠네사진관 ', '서울2호선 홍대입구역 내선 7-2 / 외선 4-2', '서울5호선 목동역 상일동 마천행 6-4', '서울9호선 동작역 종합운동장행 2-2'] Innisfree 오목교역점
# ['서울3호선 구파발역 대화행 8-4 / 오금행 3-1', '서울3호선 안국역 대화행 9-2 / 오금행 2-3', '서울1호선 종로3가역 인천 신창행 5-1', '서울1호선 서울역 소요산행 9-1 / 인천 신창행 3-1'] Innisfree 동대문디자인플라자D살림터점
# ['서울9호선 노량진역 종합운동장 방면 2-4', '서울2호선 종합운동장역 외선 9-1', '분당선 강남구청역 수원방면 5-3', '분당선 선릉역 수원방면 3-4', '서울9호선 종합운동장역 (급행)김포공항 방면 2-4/ 종합운동장 방면 2-4'] CU 공군회관점
# ['분당선 351335', '분당선 강남구청역 수원방면 5-3'] CGV 송파점
# form3
# ['잇텐고10.5 ', '서울2호선 홍대입구역 내선 3-1 / 외선 8-3', '서울5호선 을지로4가역 방화행 7-4 / 상일동 마천행 2-1', '망원동티라미수 ', '잇텐고10.5 ', 'ETUDE Lounge ', 'CAFE CMENT ', '아름다운 시선 ', '미자카야 ', '서울5호선 왕십리역 상일동 마천행 2-2', '서울5호선 마장역 상일동 마천행 2-2', '서울5호선 청구역 방화행 5-1 / 상일동 마천행 4-3', '서울5호선 5360', '서울5호선 신금호역 상일동 마천행 4-4', '이마트 에브리데이 답십리점'] 잇텐고10.5
# ['서울7호선 상봉역 부평구청 방면 5-1', '브라더후드키친 ', '알베르 '] 브라더후드키친
# ['ARITAUM 잠실지하점', 'CU 서울매트로잠실역점', '다이소 잠실점'] 서울2호선 잠실새내역 외선 3-1
# ['스타벅스 압구정점', 'CGV 압구정점/안성기상영관앞', '스타벅스 압구정점', '스타필드 코엑스몰점 /가가홈&차일드/안동찜닭&해물떡집/반하는보쌈'] 서울 강남구 신사동 609
# ['서울9호선 선정릉역 개화 방면 2-4', 'Innisfree 여의도역점'] 스타필드 코엑스몰점
# ['서울1호선 신도림역 소요산방면 9-1', '가온밀면 충무로점', '화로백서 ', '서울1호선 신도림역 인천•신창방면 9-1(급행)/소요산방면 4-2(급행)', '서울2호선 신도림역 내선 8-4 / 외선 3-1', '서울2호선 을지로3가역 외선 9-1', '서울1호선 신도림역 인천•신창방면 7-1(급행)/소요산방면 6-2(급행)'] 봄날의정원
# ['소나무생고기무한리필 ', '헬스프라자 /나눔Lotto proto', '쟝블랑제리 ', 'Salon6 어반스트리트점/9호점', '오감만족 '] 구영회참치앤초밥 신림점
# ['예원내과의원 ', '스포웰짐휘트니스 ', '예원내과의원 '] 스포웰짐휘트니스
# ['롯데백화점 스타시티점 /여성캐주얼', '바나나프라이 #넥슨아레나', '현대백화점 무역센터점 /골프/스포츠/아웃도어/트래디셔널', '스타필드 코엑스몰점 /빨라쪼/CJ푸드월드/케르반', '스타필드 코엑스몰점 /스닉솔/자라홈', '현대백화점 무역센터점 /식당가/에메랄드홀', '현대백화점 무역센터점/송 현대백화점무역센터점', '현대백화점 무역센터점 /식당가/에메랄드홀'] CGV 강동점
# ['부페웰 ', '드림악기 ', '이디야 강서교차로점', '이디야 강서교차로점', '이디야 강서교차로점', '서울1호선 종각역 소요산행 9-1', '서울4호선 수유역 당고개방면 3-1'] 부페웰
# ['서울3호선 양재역 오금방면 5-1', '서울3호선 수서역 오금방면 3-1', '서울5호선 5042', '서울5호선 오금역 방화행 6-4', '투썸플레이스 잠실역점', '투썸플레이스 잠실역점', '투썸플레이스 잠실역점', '서울6호선 신당역 봉화산행 8-4 / 응암순환행 1-1'] 서울3호선 양재역 대화방면 5-1
# ['서울5호선 신길역 상일동 마천행 4-4', '서울5호선 영등포구청역 상일동 마천행 4-4', '서울5호선 5538', '서울5호선 여의나루역 방화방면 8-4', '서울5호선 여의도역 상일동 마천행 / 4-4', '서울2호선 문래역 내선 7-1', 'CHADOL HOUSE '] 타임스퀘어/STREET CHURROS 타임스퀘어점
# ['안채 ', '올리브영 강남본점', 'Innisfree 강남직영2호점'] 안채
# ['서울5호선 애오개역 상일동 마천행 4-4', '제일제면소 쌍림점', 'Wine&Cheese Street '] Wine&Cheese Street
# ['몬비엣 ', '미스터힐링 홍대본점', '오설록 홍대점', '오빠네사진관 ', '서울2호선 홍대입구역 내선 7-2 / 외선 4-2', '서울5호선 목동역 상일동 마천행 6-4', '서울9호선 동작역 종합운동장행 2-2'] 서울 마포구 상수동 92-7
# form4
# ['잇텐고10.5 ', '서울2호선 홍대입구역 내선 3-1 / 외선 8-3', '서울5호선 을지로4가역 방화행 7-4 / 상일동 마천행 2-1', '망원동티라미수 ', '잇텐고10.5 ', 'ETUDE Lounge ', 'CAFE CMENT ', '아름다운 시선 ', '미자카야 ', '서울5호선 왕십리역 상일동 마천행 2-2', '서울5호선 마장역 상일동 마천행 2-2', '서울5호선 청구역 방화행 5-1 / 상일동 마천행 4-3', '서울5호선 5360', '서울5호선 신금호역 상일동 마천행 4-4', '이마트 에브리데이 답십리점'] CAFE CMENT
# ['서울7호선 상봉역 부평구청 방면 5-1', '브라더후드키친 ', '알베르 '] 브라더후드키친
# ['서울8호선 잠실역 모란방면 4-4', '서울8호선 잠실역 모란방면 2-2'] 서울 송파구 신천동 27
# ['부페웰 ', '드림악기 ', '이디야 강서교차로점', '이디야 강서교차로점', '이디야 강서교차로점', '서울1호선 종각역 소요산행 9-1', '서울4호선 수유역 당고개방면 3-1'] 부페웰
# ['KB국민은행 논현동지점', 'GS25 논현동부점'] CU 논현아성점
# ['서울3호선 양재역 오금방면 5-1', '서울3호선 수서역 오금방면 3-1', '서울5호선 5042', '서울5호선 오금역 방화행 6-4', '투썸플레이스 잠실역점', '투썸플레이스 잠실역점', '투썸플레이스 잠실역점', '서울6호선 신당역 봉화산행 8-4 / 응암순환행 1-1'] 서울3호선 양재역 대화방면 5-1
# ['Pandora ', '화이트스타일치과의원 치과', '서울2호선 종합운동장역 외선 5-1', '프리미어성형외과 ', '서울2호선 강변역 외선 5-1', 'HOT-T 강남점', 'GS25 구의법원점'] CGV 강변점
# ['서울삼성여성의원 /부인과'] 1001안경콘택트 잠실신천역점
# ['서울2호선 역삼역 외선 9-1', '서울2호선 강남역 외선 5-1', '얌샘김밥 삼성점'] 서울 강남구 삼성동 158-10
# ['서울5호선 신길역 상일동 마천행 4-4', '서울5호선 영등포구청역 상일동 마천행 4-4', '서울5호선 5538', '서울5호선 여의나루역 방화방면 8-4', '서울5호선 여의도역 상일동 마천행 / 4-4', '서울2호선 문래역 내선 7-1', 'CHADOL HOUSE '] CHADOL HOUSE
# ['서울9호선 종합운동장역 개화방면 2-2', '서울9호선 종합운동장역 (완행)종합운동장 방면 1-1 / 개화 방면 1-1'] 롯데마이슈퍼 코엑스점
# ['서울5호선 애오개역 상일동 마천행 4-4', '제일제면소 쌍림점', 'Wine&Cheese Street '] Wine&Cheese Street
# ['몬비엣 ', '미스터힐링 홍대본점', '오설록 홍대점', '오빠네사진관 ', '서울2호선 홍대입구역 내선 7-2 / 외선 4-2', '서울5호선 목동역 상일동 마천행 6-4', '서울9호선 동작역 종합운동장행 2-2'] 서울 마포구 상수동 92-7
# ['서울3호선 구파발역 대화행 8-4 / 오금행 3-1', '서울3호선 안국역 대화행 9-2 / 오금행 2-3', '서울1호선 종로3가역 인천 신창행 5-1', '서울1호선 서울역 소요산행 9-1 / 인천 신창행 3-1'] Innisfree 동대문디자인플라자D살림터점
# form5
# ['잇텐고10.5 ', '서울2호선 홍대입구역 내선 3-1 / 외선 8-3', '서울5호선 을지로4가역 방화행 7-4 / 상일동 마천행 2-1', '망원동티라미수 ', '잇텐고10.5 ', 'ETUDE Lounge ', 'CAFE CMENT ', '아름다운 시선 ', '미자카야 ', '서울5호선 왕십리역 상일동 마천행 2-2', '서울5호선 마장역 상일동 마천행 2-2', '서울5호선 청구역 방화행 5-1 / 상일동 마천행 4-3', '서울5호선 5360', '서울5호선 신금호역 상일동 마천행 4-4', '이마트 에브리데이 답십리점'] 잇텐고10.5
# ['서울7호선 상봉역 부평구청 방면 5-1', '브라더후드키친 ', '알베르 '] 서울 강남구 역삼동 810-13
# ['부페웰 ', '드림악기 ', '이디야 강서교차로점', '이디야 강서교차로점', '이디야 강서교차로점', '서울1호선 종각역 소요산행 9-1', '서울4호선 수유역 당고개방면 3-1'] 부페웰
# ['W CAFE 위메프더블유까페', '보쌈마을 본점', 'W CAFE 위메프더블유까페', '카레마치 ', '서울2호선 삼성역 내선 5-1 / 외선 6-4'] 서울 강남구 삼성동 168-8
# ['Pandora ', '화이트스타일치과의원 치과', '서울2호선 종합운동장역 외선 5-1', '프리미어성형외과 ', '서울2호선 강변역 외선 5-1', 'HOT-T 강남점', 'GS25 구의법원점'] 이마트 자양점 /식품/비식품
# ['서울삼성여성의원 /부인과'] 서울삼성여성의원 /부인과 located at 서울 송파구 신천동 7-19 at 14 on 01-05-2018.
# ['서울7호선 노원역 장암 방면 4-4 / 부평구청 방면 4-4', '서울7호선 뚝섬유원지역 장암 방면 4-4', '서울7호선 노원역 장암 방면 6-4 / 부평구청 방면 2-4', 'ETAM 강남점', '서울7호선 강남구청역 부평구청 방면 2-2', 'Watsons 논현역점', '스타벅스 반포역점'] 서울 강남구 역삼동 814-5
# ['서울9호선 종합운동장역 개화방면 2-2', '서울9호선 종합운동장역 (완행)종합운동장 방면 1-1 / 개화 방면 1-1'] 서울 송파구 잠실동 11
# ['서울5호선 광화문역 /상일동마천방면2-2'] 서울5호선 광화문역
# ['안채 ', '올리브영 강남본점', 'Innisfree 강남직영2호점'] 안채
# ['서울5호선 애오개역 상일동 마천행 4-4', '제일제면소 쌍림점', 'Wine&Cheese Street '] 서울 마포구 아현동 610-1
# ['첸 ', 'cafe MAMAS 역삼점', '스타벅스 교대역점', '서울2호선 교대역 내선 3-1'] 서울 강남구 역삼1동 746-12
# ['서울3호선 구파발역 대화행 8-4 / 오금행 3-1', '서울3호선 안국역 대화행 9-2 / 오금행 2-3', '서울1호선 종로3가역 인천 신창행 5-1', '서울1호선 서울역 소요산행 9-1 / 인천 신창행 3-1'] 서울 은평구 진관동 86-28
# ['서울9호선 노량진역 종합운동장 방면 2-4', '서울2호선 종합운동장역 외선 9-1', '분당선 강남구청역 수원방면 5-3', '분당선 선릉역 수원방면 3-4', '서울9호선 종합운동장역 (급행)김포공항 방면 2-4/ 종합운동장 방면 2-4'] 서울 동작구 대방동 354-1
# ['분당선 351335', '분당선 강남구청역 수원방면 5-3'] 서울 중구 봉래동2가 122-21
# form6
# ['잇텐고10.5 ', '서울2호선 홍대입구역 내선 3-1 / 외선 8-3', '서울5호선 을지로4가역 방화행 7-4 / 상일동 마천행 2-1', '망원동티라미수 ', '잇텐고10.5 ', 'ETUDE Lounge ', 'CAFE CMENT ', '아름다운 시선 ', '미자카야 ', '서울5호선 왕십리역 상일동 마천행 2-2', '서울5호선 마장역 상일동 마천행 2-2', '서울5호선 청구역 방화행 5-1 / 상일동 마천행 4-3', '서울5호선 5360', '서울5호선 신금호역 상일동 마천행 4-4', '이마트 에브리데이 답십리점'] 서울 마포구 합정동 386-6
# ['서울7호선 상봉역 부평구청 방면 5-1', '브라더후드키친 ', '알베르 '] 서울 강남구 역삼동 810-13
나/러브캣/라코스테ACC', '현대시티아울렛 가산점 /영캐주얼. 구두. 핸드백액세서리/시슬리/에고이스트/매긴/세컨스킨/CC콜렉트/VOV/티렌/더아이잗/더틸버리/베네통/커밍스텝', '현대시티아울렛 가산점 /영캐주얼. 구두. 핸드백액세서리/고체/소다', '현대시티아울렛 가산점/HAZZYS 현대아울렛가산점', '현대시티아울렛 가산점 /여성패션. 골프. 아동/ 앤클라인/아이잗바바/쁘렝땅/요하넥스/캐리스노트/발렌시아'] 서울 금천구 가산동 60-8
# ['서울3호선 교대역 오금방면 7-1', '서울3호선 양재역 대화방면 7-1', '서울3호선 양재역 대화방면 5-1', '분당선 수서역 왕십리방면 5-3', '서울3호선 교대역 오금방면 5-1', '서울3호선 매봉역 오금방면 5-1', '분당선 대모산입구역 왕십리방면 5-3', '서울3호선 교대역 오금방면 7-1', '서울3호선 수서역 오금방면 7-1', '서울3호선 매봉역 오금방면 9-1'] 서울3호선 도곡역 대화방면 5-1
# ['현대백화점 압구정본점 /수입부티크 외', '현대백화점 압구정본점 /남성패션/타이/셔츠/골프/아웃도어', '현대백화점 압구정본점 /남성패션 외'] 서울 강남구 압구정동 429
# ['서울5호선 오목교역 상일동 마천행 4-4', '서울5호선 5569', '서울5호선 을지로4가역 방화행 4-3 / 상일동 마천행 5-2', '서울5호선 종로3가역 방화행 4-3 / 상일동 마천행 5-1', '서울2호선 을지로4가역 내선 7-1'] 서울 양천구 목동 406-30
# ['경의중앙선 디지털미디어시티역 지평방면 2-2', '서울1호선 311641', '경의중앙선 회기역 / 경춘선 회기역 /문산방면6-4/청량리방면6-4', '경의중앙선 효창공원앞역 지평행 2-2', '서울1호선 청량리역 소요산행 3-2 / 인천 신창행 8-4', '김밥타운 노량진점', 'THE FACE SHOP 노량진역직영점', '경의중앙선 디지털미디어시티역 서울역행 2-2', '경의중앙선 홍대입구역 문산행 2-2', '서울1호선 용산역 / 경의중앙선 용산역 동인천 천안급행 9-1 / 문산행 1-4', '경의중앙선 디지털미디어시티역 문산행 4-3'] 스타필드 코엑스몰점/Saboten 코엑스점
# ['서울8호선 송파역 모란방면 4-4', '분당선 복정역 왕십리방면 2-2', '분당선 351941'] 서울 송파구 잠실동 209-1
# ['하이마트 양재점', '서울3호선 양재역 대화방면 5-1', '신분당선 청계산입구역 강남방면 2-2', '신세계백화점 강남점 /신세계 푸드마켓/푸드홀', '신세계백화점 강남점 /화장품/잡화/해외유명브랜드', '서울3호선 남부터미널역 오금방면 7-1', '서울3호선 고속터미널역 오금방면 9-1'] 서울 서초구 방배동 750-20
# ['서울2호선 잠실역 외선 3-1', '서울7호선 고속터미널역 장암 방면 6-4', '서울7호선 가산디지털단지역 장암 방면 6-4', '서울7호선 대림역 장암 방면 6-4', '서울8호선 가락시장역 모란방면 2-2', '서울3호선 고속터미널역 오금방면 3-1'] 서울7호선 고속터미널역 장암 방면 6-4 located at 서울 서초구 반포동 118-9 at 19 on 12-16-2017
# ['서울9호선 봉은사역 개화 방면 2-4', '스타벅스 양평동점', '서울9호선 당산역 개화방면 4-4/종합운동장방면 1-1'] 서울 강남구 삼성동 111-8
# ['공릉동멸치국수 굽은다리역점', 'CGV 천호점/매표소', 'CGV 천호점/매표소', '우이신설선 성신여대입구역 북한산우이방면 2-2', '우이신설선 보문역 북한산우이방면 2-2', '동대문도서관 ', '우이신설선 4.19민주묘지역 신설동방면 1-1', '서울5호선 5709'] 서울 강동구 명일동 351-14
# ['부페웰 ', '드림악기 ', '이디야 강서교차로점', '이디야 강서교차로점', '이디야 강서교차로점', '서울1호선 종각역 소요산행 9-1', '서울4호선 수유역 당고개방면 3-1'] 명성오리
# ['KB국민은행 논현동지점', 'GS25 논현동부점'] 서울 강남구 논현동 237-10
# ['W CAFE 위메프더블유까페', '보쌈마을 본점', 'W CAFE 위메프더블유까페', '카레마치 ', '서울2호선 삼성역 내선 5-1 / 외선 6-4'] 서울 강남구 삼성동 172-66
# ['Pandora ', '화이트스타일치과의원 치과', '서울2호선 종합운동장역 외선 5-1', '프리미어성형외과 ', '서울2호선 강변역 외선 5-1', 'HOT-T 강남점', 'GS25 구의법원점'] 이마트 자양점 /식품/비식품
# ['서울7호선 노원역 장암 방면 4-4 / 부평구청 방면 4-4', '서울7호선 뚝섬유원지역 장암 방면 4-4', '서울7호선 노원역 장암 방면 6-4 / 부평구청 방면 2-4', 'ETAM 강남점', '서울7호선 강남구청역 부평구청 방면 2-2', 'Watsons 논현역점', '스타벅스 반포역점'] 서울 강남구 역삼동 814-6
# ['서울9호선 종합운동장역 개화방면 2-2', '서울9호선 종합운동장역 (완행)종합운동장 방면 1-1 / 개화 방면 1-1'] 서울 송파구 잠실동 11
# ['서울5호선 광화문역 /상일동마천방면2-2'] 서울5호선 광화문역
# ['안채 ', '올리브영 강남본점', 'Innisfree 강남직영2호점'] 서울 서초구 서초동 1305-8
# ['서울5호선 애오개역 상일동 마천행 4-4', '제일제면소 쌍림점', 'Wine&Cheese Street '] 서울 마포구 아현동 610-1
# ['첸 ', 'cafe MAMAS 역삼점', '스타벅스 교대역점', '서울2호선 교대역 내선 3-1'] 서울 서초구 서초동 1693-3
# ['서울3호선 구파발역 대화행 8-4 / 오금행 3-1', '서울3호선 안국역 대화행 9-2 / 오금행 2-3', '서울1호선 종로3가역 인천 신창행 5-1', '서울1호선 서울역 소요산행 9-1 / 인천 신창행 3-1'] 서울 종로구 경운동 95
# ['서울9호선 노량진역 종합운동장 방면 2-4', '서울2호선 종합운동장역 외선 9-1', '분당선 강남구청역 수원방면 5-3', '분당선 선릉역 수원방면 3-4', '서울9호선 종합운동장역 (급행)김포공항 방면 2-4/ 종합운동장 방면 2-4'] 서울 동작구 대방동 354-1
# ['분당선 351335', '분당선 강남구청역 수원방면 5-3'] CGV 송파점

# %%
print(sum(ask_place_form1_score)/100)
print(sum(ask_place_form2_score)/100)
print(sum(ask_place_form3_score)/100)
print(sum(ask_place_form4_score)/100)
print(sum(ask_place_form5_score)/100)
print(sum(ask_place_form6_score)/100)
# Out:
# 0.54
# 0.52
# 0.67
# 0.58
# 0.43
# 0.29
